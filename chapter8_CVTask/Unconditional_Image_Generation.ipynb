# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/Colab Notebooks/transformer_learn/Kaggle"

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/transformer_learn/Kaggle
! kaggle datasets download -d validmodel/indo-fashion-dataset
# Out:
# /content/drive/MyDrive/Colab Notebooks/transformer_learn/Kaggle
# Downloading indo-fashion-dataset.zip to /content/drive/MyDrive/Colab Notebooks/transformer_learn/Kaggle
# 100% 2.69G/2.69G [01:47<00:00, 27.9MB/s]
# 100% 2.69G/2.69G [01:47<00:00, 26.9MB/s]

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/transformer_learn/Kaggle
# !unzip indo-fashion-dataset.zip
# !rm indo-fashion-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/val/3250.jpeg
#   inflating: images/val/3251.jpeg
#   inflating: images/val/3252.jpeg
#   inflating: images/val/3253.jpeg
#   inflating: images/val/3254.jpeg
#   inflating: images/val/3255.jpeg
#   inflating: images/val/3256.jpeg
#   inflating: images/val/3257.jpeg
#   inflating: images/val/3258.jpeg
#   inflating: images/val/3259.jpeg
#   inflating: images/val/326.jpeg
#   inflating: images/val/3260.jpeg
#   inflating: images/val/3261.jpeg
#   inflating: images/val/3262.jpeg
#   inflating: images/val/3263.jpeg
#   inflating: images/val/3264.jpeg
#   inflating: images/val/3265.jpeg
#   inflating: images/val/3266.jpeg
#   inflating: images/val/3267.jpeg
#   inflating: images/val/3268.jpeg
#   inflating: images/val/3269.jpeg
#   inflating: images/val/327.jpeg
#   inflating: images/val/3270.jpeg
#   inflating: images/val/3271.jpeg
#   inflating: images/val/3272.jpeg
#   inflating: images/val/3273.jpeg
#   inflating: images/val/3274.jpeg
#   inflating: images/val/3275.jpeg
#   inflating: images/val/3276.jpeg
#   inflating: images/val/3277.jpeg
#   inflating: images/val/3278.jpeg
#   inflating: images/val/3279.jpeg
#   inflating: images/val/328.jpeg
#   inflating: images/val/3280.jpeg
#   inflating: images/val/3281.jpeg
#   inflating: images/val/3282.jpeg
#   inflating: images/val/3283.jpeg
#   inflating: images/val/3284.jpeg
#   inflating: images/val/3285.jpeg
#   inflating: images/val/3286.jpeg
#   inflating: images/val/3287.jpeg
#   inflating: images/val/3288.jpeg
#   inflating: images/val/3289.jpeg
#   inflating: images/val/329.jpeg
#   inflating: images/val/3290.jpeg
#   inflating: images/val/3291.jpeg
#   inflating: images/val/3292.jpeg
#   inflating: images/val/3293.jpeg
#   inflating: images/val/3294.jpeg
#   inflating: images/val/3295.jpeg
#   inflating: images/val/3296.jpeg
#   inflating: images/val/3297.jpeg
#   inflating: images/val/3298.jpeg
#   inflating: images/val/3299.jpeg
#   inflating: images/val/33.jpeg
#   inflating: images/val/330.jpeg
#   inflating: images/val/3300.jpeg
#   inflating: images/val/3301.jpeg
#   inflating: images/val/3302.jpeg
#   inflating: images/val/3303.jpeg
#   inflating: images/val/3304.jpeg
#   inflating: images/val/3305.jpeg
#   inflating: images/val/3306.jpeg
#   inflating: images/val/3307.jpeg
#   inflating: images/val/3308.jpeg
#   inflating: images/val/3309.jpeg
#   inflating: images/val/331.jpeg
#   inflating: images/val/3310.jpeg
#   inflating: images/val/3311.jpeg
#   inflating: images/val/3312.jpeg
#   inflating: images/val/3313.jpeg
#   inflating: images/val/3314.jpeg
#   inflating: images/val/3315.jpeg
#   inflating: images/val/3316.jpeg
#   inflating: images/val/3317.jpeg
#   inflating: images/val/3318.jpeg
#   inflating: images/val/3319.jpeg
#   inflating: images/val/332.jpeg
#   inflating: images/val/3320.jpeg
#   inflating: images/val/3321.jpeg
#   inflating: images/val/3322.jpeg
#   inflating: images/val/3323.jpeg
#   inflating: images/val/3324.jpeg
#   inflating: images/val/3325.jpeg
#   inflating: images/val/3326.jpeg
#   inflating: images/val/3327.jpeg
#   inflating: images/val/3328.jpeg
#   inflating: images/val/3329.jpeg
#   inflating: images/val/333.jpeg
#   inflating: images/val/3330.jpeg
#   inflating: images/val/3331.jpeg
#   inflating: images/val/3332.jpeg
#   inflating: images/val/3333.jpeg
#   inflating: images/val/3334.jpeg
#   inflating: images/val/3335.jpeg
#   inflating: images/val/3336.jpeg
#   inflating: images/val/3337.jpeg
#   inflating: images/val/3338.jpeg
#   inflating: images/val/3339.jpeg
#   inflating: images/val/334.jpeg
#   inflating: images/val/3340.jpeg
#   inflating: images/val/3341.jpeg
#   inflating: images/val/3342.jpeg
#   inflating: images/val/3343.jpeg
#   inflating: images/val/3344.jpeg
#   inflating: images/val/3345.jpeg
#   inflating: images/val/3346.jpeg
#   inflating: images/val/3347.jpeg
#   inflating: images/val/3348.jpeg
#   inflating: images/val/3349.jpeg
#   inflating: images/val/335.jpeg
#   inflating: images/val/3350.jpeg
#   inflating: images/val/3351.jpeg
#   inflating: images/val/3352.jpeg
#   inflating: images/val/3353.jpeg
#   inflating: images/val/3354.jpeg
#   inflating: images/val/3355.jpeg
#   inflating: images/val/3356.jpeg
#   inflating: images/val/3357.jpeg
#   inflating: images/val/3358.jpeg
#   inflating: images/val/3359.jpeg
#   inflating: images/val/336.jpeg
#   inflating: images/val/3360.jpeg
#   inflating: images/val/3361.jpeg
#   inflating: images/val/3362.jpeg
#   inflating: images/val/3363.jpeg
#   inflating: images/val/3364.jpeg
#   inflating: images/val/3365.jpeg
#   inflating: images/val/3366.jpeg
#   inflating: images/val/3367.jpeg
#   inflating: images/val/3368.jpeg
#   inflating: images/val/3369.jpeg
#   inflating: images/val/337.jpeg
#   inflating: images/val/3370.jpeg
#   inflating: images/val/3371.jpeg
#   inflating: images/val/3372.jpeg
#   inflating: images/val/3373.jpeg
#   inflating: images/val/3374.jpeg
#   inflating: images/val/3375.jpeg
#   inflating: images/val/3376.jpeg
#   inflating: images/val/3377.jpeg
#   inflating: images/val/3378.jpeg
#   inflating: images/val/3379.jpeg
#   inflating: images/val/338.jpeg
#   inflating: images/val/3380.jpeg
#   inflating: images/val/3381.jpeg
#   inflating: images/val/3382.jpeg
#   inflating: images/val/3383.jpeg
#   inflating: images/val/3384.jpeg
#   inflating: images/val/3385.jpeg
#   inflating: images/val/3386.jpeg
#   inflating: images/val/3387.jpeg
#   inflating: images/val/3388.jpeg
#   inflating: images/val/3389.jpeg
#   inflating: images/val/339.jpeg
#   inflating: images/val/3390.jpeg
#   inflating: images/val/3391.jpeg
#   inflating: images/val/3392.jpeg
#   inflating: images/val/3393.jpeg
#   inflating: images/val/3394.jpeg
#   inflating: images/val/3395.jpeg
#   inflating: images/val/3396.jpeg
#   inflating: images/val/3397.jpeg
#   inflating: images/val/3398.jpeg
#   inflating: images/val/3399.jpeg
#   inflating: images/val/34.jpeg
#   inflating: images/val/340.jpeg
#   inflating: images/val/3400.jpeg
#   inflating: images/val/3401.jpeg
#   inflating: images/val/3402.jpeg
#   inflating: images/val/3403.jpeg
#   inflating: images/val/3404.jpeg
#   inflating: images/val/3405.jpeg
#   inflating: images/val/3406.jpeg
#   inflating: images/val/3407.jpeg
#   inflating: images/val/3408.jpeg
#   inflating: images/val/3409.jpeg
#   inflating: images/val/341.jpeg
#   inflating: images/val/3410.jpeg
#   inflating: images/val/3411.jpeg
#   inflating: images/val/3412.jpeg
#   inflating: images/val/3413.jpeg
#   inflating: images/val/3414.jpeg
#   inflating: images/val/3415.jpeg
#   inflating: images/val/3416.jpeg
#   inflating: images/val/3417.jpeg
#   inflating: images/val/3418.jpeg
#   inflating: images/val/3419.jpeg
#   inflating: images/val/342.jpeg
#   inflating: images/val/3420.jpeg
#   inflating: images/val/3421.jpeg
#   inflating: images/val/3422.jpeg
#   inflating: images/val/3423.jpeg
#   inflating: images/val/3424.jpeg
#   inflating: images/val/3425.jpeg
#   inflating: images/val/3426.jpeg
#   inflating: images/val/3427.jpeg
#   inflating: images/val/3428.jpeg
#   inflating: images/val/3429.jpeg
#   inflating: images/val/343.jpeg
#   inflating: images/val/3430.jpeg
#   inflating: images/val/3431.jpeg
#   inflating: images/val/3432.jpeg
#   inflating: images/val/3433.jpeg
#   inflating: images/val/3434.jpeg
#   inflating: images/val/3435.jpeg
#   inflating: images/val/3436.jpeg
#   inflating: images/val/3437.jpeg
#   inflating: images/val/3438.jpeg
#   inflating: images/val/3439.jpeg
#   inflating: images/val/344.jpeg
#   inflating: images/val/3440.jpeg
#   inflating: images/val/3441.jpeg
#   inflating: images/val/3442.jpeg
#   inflating: images/val/3443.jpeg
#   inflating: images/val/3444.jpeg
#   inflating: images/val/3445.jpeg
#   inflating: images/val/3446.jpeg
#   inflating: images/val/3447.jpeg
#   inflating: images/val/3448.jpeg
#   inflating: images/val/3449.jpeg
#   inflating: images/val/345.jpeg
#   inflating: images/val/3450.jpeg
#   inflating: images/val/3451.jpeg
#   inflating: images/val/3452.jpeg
#   inflating: images/val/3453.jpeg
#   inflating: images/val/3454.jpeg
#   inflating: images/val/3455.jpeg
#   inflating: images/val/3456.jpeg
#   inflating: images/val/3457.jpeg
#   inflating: images/val/3458.jpeg
#   inflating: images/val/3459.jpeg
#   inflating: images/val/346.jpeg
#   inflating: images/val/3460.jpeg
#   inflating: images/val/3461.jpeg
#   inflating: images/val/3462.jpeg
#   inflating: images/val/3463.jpeg
#   inflating: images/val/3464.jpeg
#   inflating: images/val/3465.jpeg
#   inflating: images/val/3466.jpeg
#   inflating: images/val/3467.jpeg
#   inflating: images/val/3468.jpeg
#   inflating: images/val/3469.jpeg
#   inflating: images/val/347.jpeg
#   inflating: images/val/3470.jpeg
#   inflating: images/val/3471.jpeg
#   inflating: images/val/3472.jpeg
#   inflating: images/val/3473.jpeg
#   inflating: images/val/3474.jpeg
#   inflating: images/val/3475.jpeg
#   inflating: images/val/3476.jpeg
#   inflating: images/val/3477.jpeg
#   inflating: images/val/3478.jpeg
#   inflating: images/val/3479.jpeg
#   inflating: images/val/348.jpeg
#   inflating: images/val/3480.jpeg
#   inflating: images/val/3481.jpeg
#   inflating: images/val/3482.jpeg
#   inflating: images/val/3483.jpeg
#   inflating: images/val/3484.jpeg
#   inflating: images/val/3485.jpeg
#   inflating: images/val/3486.jpeg
#   inflating: images/val/3487.jpeg
#   inflating: images/val/3488.jpeg
#   inflating: images/val/3489.jpeg
#   inflating: images/val/349.jpeg
#   inflating: images/val/3490.jpeg
#   inflating: images/val/3491.jpeg
#   inflating: images/val/3492.jpeg
#   inflating: images/val/3493.jpeg
#   inflating: images/val/3494.jpeg
#   inflating: images/val/3495.jpeg
#   inflating: images/val/3496.jpeg
#   inflating: images/val/3497.jpeg
#   inflating: images/val/3498.jpeg
#   inflating: images/val/3499.jpeg
#   inflating: images/val/35.jpeg
#   inflating: images/val/350.jpeg
#   inflating: images/val/3500.jpeg
#   inflating: images/val/3501.jpeg
#   inflating: images/val/3502.jpeg
#   inflating: images/val/3503.jpg
#   inflating: images/val/3504.jpeg
#   inflating: images/val/3505.jpeg
#   inflating: images/val/3506.jpeg
#   inflating: images/val/3507.jpg
#   inflating: images/val/3508.jpeg
#   inflating: images/val/3509.jpeg
#   inflating: images/val/351.jpeg
#   inflating: images/val/3510.jpeg
#   inflating: images/val/3511.jpg
#   inflating: images/val/3512.jpeg
#   inflating: images/val/3513.jpeg
#   inflating: images/val/3514.jpeg
#   inflating: images/val/3515.jpeg
#   inflating: images/val/3516.jpeg
#   inflating: images/val/3517.jpg
#   inflating: images/val/3518.jpeg
#   inflating: images/val/3519.jpeg
#   inflating: images/val/352.jpeg
#   inflating: images/val/3520.jpeg
#   inflating: images/val/3521.jpeg
#   inflating: images/val/3522.jpg
#   inflating: images/val/3523.jpeg
#   inflating: images/val/3524.jpeg
#   inflating: images/val/3525.jpeg
#   inflating: images/val/3526.jpeg
#   inflating: images/val/3527.jpg
#   inflating: images/val/3528.jpeg
#   inflating: images/val/3529.jpeg
#   inflating: images/val/353.jpeg
#   inflating: images/val/3530.jpeg
#   inflating: images/val/3531.jpeg
#   inflating: images/val/3532.jpeg
#   inflating: images/val/3533.jpeg
#   inflating: images/val/3534.jpeg
#   inflating: images/val/3535.jpeg
#   inflating: images/val/3536.jpeg
#   inflating: images/val/3537.jpeg
#   inflating: images/val/3538.jpeg
#   inflating: images/val/3539.jpg
#   inflating: images/val/354.jpeg
#   inflating: images/val/3540.jpeg
#   inflating: images/val/3541.jpeg
#   inflating: images/val/3542.jpg
#   inflating: images/val/3543.jpeg
#   inflating: images/val/3544.jpeg
#   inflating: images/val/3545.jpeg
#   inflating: images/val/3546.jpeg
#   inflating: images/val/3547.jpg
#   inflating: images/val/3548.jpeg
#   inflating: images/val/3549.jpeg
#   inflating: images/val/355.jpeg
#   inflating: images/val/3550.jpg
#   inflating: images/val/3551.jpeg
#   inflating: images/val/3552.jpeg
#   inflating: images/val/3553.jpeg
#   inflating: images/val/3554.jpg
#   inflating: images/val/3555.jpeg
#   inflating: images/val/3556.jpeg
#   inflating: images/val/3557.jpeg
#   inflating: images/val/3558.jpg
#   inflating: images/val/3559.jpeg
#   inflating: images/val/356.jpeg
#   inflating: images/val/3560.jpeg
#   inflating: images/val/3561.jpeg
#   inflating: images/val/3562.jpeg
#   inflating: images/val/3563.jpeg
#   inflating: images/val/3564.jpeg
#   inflating: images/val/3565.jpeg
#   inflating: images/val/3566.jpeg
#   inflating: images/val/3567.jpeg
#   inflating: images/val/3568.jpeg
#   inflating: images/val/3569.jpeg
#   inflating: images/val/357.jpeg
#   inflating: images/val/3570.jpg
#   inflating: images/val/3571.jpeg
#   inflating: images/val/3572.jpg
#   inflating: images/val/3573.jpeg
#   inflating: images/val/3574.jpeg
#   inflating: images/val/3575.jpeg
#   inflating: images/val/3576.jpeg
#   inflating: images/val/3577.jpg
#   inflating: images/val/3578.jpg
#   inflating: images/val/3579.jpeg
#   inflating: images/val/358.jpeg
#   inflating: images/val/3580.jpeg
#   inflating: images/val/3581.jpeg
#   inflating: images/val/3582.jpeg
#   inflating: images/val/3583.jpeg
#   inflating: images/val/3584.jpeg
#   inflating: images/val/3585.jpeg
#   inflating: images/val/3586.jpeg
#   inflating: images/val/3587.jpg
#   inflating: images/val/3588.jpeg
#   inflating: images/val/3589.jpeg
#   inflating: images/val/359.jpeg
#   inflating: images/val/3590.jpeg
#   inflating: images/val/3591.jpg
#   inflating: images/val/3592.jpeg
#   inflating: images/val/3593.jpeg
#   inflating: images/val/3594.jpeg
#   inflating: images/val/3595.jpeg
#   inflating: images/val/3596.jpg
#   inflating: images/val/3597.jpeg
#   inflating: images/val/3598.jpeg
#   inflating: images/val/3599.jpeg
#   inflating: images/val/36.jpeg
#   inflating: images/val/360.jpeg
#   inflating: images/val/3600.jpeg
#   inflating: images/val/3601.jpeg
#   inflating: images/val/3602.jpeg
#   inflating: images/val/3603.jpeg
#   inflating: images/val/3604.jpg
#   inflating: images/val/3605.jpeg
#   inflating: images/val/3606.jpg
#   inflating: images/val/3607.jpeg
#   inflating: images/val/3608.jpeg
#   inflating: images/val/3609.jpeg
#   inflating: images/val/361.jpeg
#   inflating: images/val/3610.jpeg
#   inflating: images/val/3611.jpeg
#   inflating: images/val/3612.jpeg
#   inflating: images/val/3613.jpg
#   inflating: images/val/3614.jpeg
#   inflating: images/val/3615.jpeg
#   inflating: images/val/3616.jpeg
#   inflating: images/val/3617.jpeg
#   inflating: images/val/3618.jpeg
#   inflating: images/val/3619.jpeg
#   inflating: images/val/362.jpeg
#   inflating: images/val/3620.jpeg
#   inflating: images/val/3621.jpeg
#   inflating: images/val/3622.jpeg
#   inflating: images/val/3623.jpg
#   inflating: images/val/3624.jpeg
#   inflating: images/val/3625.jpg
#   inflating: images/val/3626.jpeg
#   inflating: images/val/3627.jpeg
#   inflating: images/val/3628.jpeg
#   inflating: images/val/3629.jpeg
#   inflating: images/val/363.jpeg
#   inflating: images/val/3630.jpeg
#   inflating: images/val/3631.jpeg
#   inflating: images/val/3632.jpeg
#   inflating: images/val/3633.jpeg
#   inflating: images/val/3634.jpeg
#   inflating: images/val/3635.jpeg
#   inflating: images/val/3636.jpg
#   inflating: images/val/3637.jpeg
#   inflating: images/val/3638.jpeg
#   inflating: images/val/3639.jpeg
#   inflating: images/val/364.jpeg
#   inflating: images/val/3640.jpg
#   inflating: images/val/3641.jpeg
#   inflating: images/val/3642.jpeg
#   inflating: images/val/3643.jpeg
#   inflating: images/val/3644.jpeg
#   inflating: images/val/3645.jpeg
#   inflating: images/val/3646.jpeg
#   inflating: images/val/3647.jpeg
#   inflating: images/val/3648.jpeg
#   inflating: images/val/3649.jpeg
#   inflating: images/val/365.jpeg
#   inflating: images/val/3650.jpeg
#   inflating: images/val/3651.jpeg
#   inflating: images/val/3652.jpeg
#   inflating: images/val/3653.jpeg
#   inflating: images/val/3654.jpeg
#   inflating: images/val/3655.jpg
#   inflating: images/val/3656.jpeg
#   inflating: images/val/3657.jpeg
#   inflating: images/val/3658.jpg
#   inflating: images/val/3659.jpeg
#   inflating: images/val/366.jpeg
#   inflating: images/val/3660.jpeg
#   inflating: images/val/3661.jpeg
#   inflating: images/val/3662.jpeg
#   inflating: images/val/3663.jpg
#   inflating: images/val/3664.jpg
#   inflating: images/val/3665.jpeg
#   inflating: images/val/3666.jpeg
#   inflating: images/val/3667.jpeg
#   inflating: images/val/3668.jpeg
#   inflating: images/val/3669.jpeg
#   inflating: images/val/367.jpeg
#   inflating: images/val/3670.jpg
#   inflating: images/val/3671.jpeg
#   inflating: images/val/3672.jpeg
#   inflating: images/val/3673.jpeg
#   inflating: images/val/3674.jpg
#   inflating: images/val/3675.jpeg
#   inflating: images/val/3676.jpeg
#   inflating: images/val/3677.jpg
#   inflating: images/val/3678.jpeg
#   inflating: images/val/3679.jpeg
#   inflating: images/val/368.jpeg
#   inflating: images/val/3680.jpeg
#   inflating: images/val/3681.jpeg
#   inflating: images/val/3682.jpeg
#   inflating: images/val/3683.jpeg
#   inflating: images/val/3684.jpeg
#   inflating: images/val/3685.jpeg
#   inflating: images/val/3686.jpeg
#   inflating: images/val/3687.jpeg
#   inflating: images/val/3688.jpeg
#   inflating: images/val/3689.jpeg
#   inflating: images/val/369.jpeg
#   inflating: images/val/3690.jpg
#   inflating: images/val/3691.jpeg
#   inflating: images/val/3692.jpg
#   inflating: images/val/3693.jpeg
#   inflating: images/val/3694.jpeg
#   inflating: images/val/3695.jpg
#   inflating: images/val/3696.jpeg
#   inflating: images/val/3697.jpg
#   inflating: images/val/3698.jpeg
#   inflating: images/val/3699.jpeg
#   inflating: images/val/37.jpeg
#   inflating: images/val/370.jpeg
#   inflating: images/val/3700.jpeg
#   inflating: images/val/3701.jpg
#   inflating: images/val/3702.jpg
#   inflating: images/val/3703.jpeg
#   inflating: images/val/3704.jpeg
#   inflating: images/val/3705.jpeg
#   inflating: images/val/3706.jpeg
#   inflating: images/val/3707.jpeg
#   inflating: images/val/3708.jpeg
#   inflating: images/val/3709.jpeg
#   inflating: images/val/371.jpeg
#   inflating: images/val/3710.jpeg
#   inflating: images/val/3711.jpeg
#   inflating: images/val/3712.jpeg
#   inflating: images/val/3713.jpeg
#   inflating: images/val/3714.jpeg
#   inflating: images/val/3715.jpg
#   inflating: images/val/3716.jpeg
#   inflating: images/val/3717.jpeg
#   inflating: images/val/3718.jpeg
#   inflating: images/val/3719.jpeg
#   inflating: images/val/372.jpeg
#   inflating: images/val/3720.jpeg
#   inflating: images/val/3721.jpeg
#   inflating: images/val/3722.jpeg
#   inflating: images/val/3723.jpeg
#   inflating: images/val/3724.jpeg
#   inflating: images/val/3725.jpeg
#   inflating: images/val/3726.jpeg
#   inflating: images/val/3727.jpeg
#   inflating: images/val/3728.jpeg
#   inflating: images/val/3729.jpg
#   inflating: images/val/373.jpeg
#   inflating: images/val/3730.jpeg
#   inflating: images/val/3731.jpeg
#   inflating: images/val/3732.jpeg
#   inflating: images/val/3733.jpeg
#   inflating: images/val/3734.jpeg
#   inflating: images/val/3735.jpeg
#   inflating: images/val/3736.jpeg
#   inflating: images/val/3737.jpeg
#   inflating: images/val/3738.jpeg
#   inflating: images/val/3739.jpeg
#   inflating: images/val/374.jpeg
#   inflating: images/val/3740.jpg
#   inflating: images/val/3741.jpg
#   inflating: images/val/3742.jpeg
#   inflating: images/val/3743.jpeg
#   inflating: images/val/3744.jpg
#   inflating: images/val/3745.jpg
#   inflating: images/val/3746.jpeg
#   inflating: images/val/3747.jpeg
#   inflating: images/val/3748.jpeg
#   inflating: images/val/3749.jpg
#   inflating: images/val/375.jpeg
#   inflating: images/val/3750.jpeg
#   inflating: images/val/3751.jpg
#   inflating: images/val/3752.jpeg
#   inflating: images/val/3753.jpeg
#   inflating: images/val/3754.jpeg
#   inflating: images/val/3755.jpeg
#   inflating: images/val/3756.jpeg
#   inflating: images/val/3757.jpeg
#   inflating: images/val/3758.jpeg
#   inflating: images/val/3759.jpeg
#   inflating: images/val/376.jpeg
#   inflating: images/val/3760.jpeg
#   inflating: images/val/3761.jpg
#   inflating: images/val/3762.jpg
#   inflating: images/val/3763.jpeg
#   inflating: images/val/3764.jpeg
#   inflating: images/val/3765.jpeg
#   inflating: images/val/3766.jpeg
#   inflating: images/val/3767.jpeg
#   inflating: images/val/3768.jpeg
#   inflating: images/val/3769.jpeg
#   inflating: images/val/377.jpeg
#   inflating: images/val/3770.jpg
#   inflating: images/val/3771.jpg
#   inflating: images/val/3772.jpeg
#   inflating: images/val/3773.jpeg
#   inflating: images/val/3774.jpg
#   inflating: images/val/3775.jpg
#   inflating: images/val/3776.jpg
#   inflating: images/val/3777.jpeg
#   inflating: images/val/3778.jpg
#   inflating: images/val/3779.jpeg
#   inflating: images/val/378.jpeg
#   inflating: images/val/3780.jpeg
#   inflating: images/val/3781.jpeg
#   inflating: images/val/3782.jpeg
#   inflating: images/val/3783.jpeg
#   inflating: images/val/3784.jpeg
#   inflating: images/val/3785.jpeg
#   inflating: images/val/3786.jpg
#   inflating: images/val/3787.jpeg
#   inflating: images/val/3788.jpeg
#   inflating: images/val/3789.jpeg
#   inflating: images/val/379.jpeg
#   inflating: images/val/3790.jpeg
#   inflating: images/val/3791.jpeg
#   inflating: images/val/3792.jpeg
#   inflating: images/val/3793.jpeg
#   inflating: images/val/3794.jpeg
#   inflating: images/val/3795.jpg
#   inflating: images/val/3796.jpeg
#   inflating: images/val/3797.jpg
#   inflating: images/val/3798.jpg
#   inflating: images/val/3799.jpeg
#   inflating: images/val/38.jpeg
#   inflating: images/val/380.jpeg
#   inflating: images/val/3800.jpeg
#   inflating: images/val/3801.jpeg
#   inflating: images/val/3802.jpeg
#   inflating: images/val/3803.jpeg
#   inflating: images/val/3804.jpeg
#   inflating: images/val/3805.jpeg
#   inflating: images/val/3806.jpg
#   inflating: images/val/3807.jpeg
#   inflating: images/val/3808.jpg
#   inflating: images/val/3809.jpeg
#   inflating: images/val/381.jpeg
#   inflating: images/val/3810.jpg
#   inflating: images/val/3811.jpeg
#   inflating: images/val/3812.jpeg
#   inflating: images/val/3813.jpeg
#   inflating: images/val/3814.jpeg
#   inflating: images/val/3815.jpeg
#   inflating: images/val/3816.jpg
#   inflating: images/val/3817.jpeg
#   inflating: images/val/3818.jpeg
#   inflating: images/val/3819.jpeg
#   inflating: images/val/382.jpeg
#   inflating: images/val/3820.jpeg
#   inflating: images/val/3821.jpg
#   inflating: images/val/3822.jpeg
#   inflating: images/val/3823.jpg
#   inflating: images/val/3824.jpeg
#   inflating: images/val/3825.jpeg
#   inflating: images/val/3826.jpeg
#   inflating: images/val/3827.jpeg
#   inflating: images/val/3828.jpeg
#   inflating: images/val/3829.jpeg
#   inflating: images/val/383.jpeg
#   inflating: images/val/3830.jpeg
#   inflating: images/val/3831.jpg
#   inflating: images/val/3832.jpeg
#   inflating: images/val/3833.jpeg
#   inflating: images/val/3834.jpeg
#   inflating: images/val/3835.jpeg
#   inflating: images/val/3836.jpg
#   inflating: images/val/3837.jpeg
#   inflating: images/val/3838.jpeg
#   inflating: images/val/3839.jpeg
#   inflating: images/val/384.jpeg
#   inflating: images/val/3840.jpg
#   inflating: images/val/3841.jpg
#   inflating: images/val/3842.jpg
#   inflating: images/val/3843.jpg
#   inflating: images/val/3844.jpeg
#   inflating: images/val/3845.jpeg
#   inflating: images/val/3846.jpeg
#   inflating: images/val/3847.jpeg
#   inflating: images/val/3848.jpeg
#   inflating: images/val/3849.jpg
#   inflating: images/val/385.jpeg
#   inflating: images/val/3850.jpeg
#   inflating: images/val/3851.jpeg
#   inflating: images/val/3852.jpg
#   inflating: images/val/3853.jpeg
#   inflating: images/val/3854.jpeg
#   inflating: images/val/3855.jpeg
#   inflating: images/val/3856.jpg
#   inflating: images/val/3857.jpg
#   inflating: images/val/3858.jpeg
#   inflating: images/val/3859.jpeg
#   inflating: images/val/386.jpeg
#   inflating: images/val/3860.jpeg
#   inflating: images/val/3861.jpeg
#   inflating: images/val/3862.jpeg
#   inflating: images/val/3863.jpeg
#   inflating: images/val/3864.jpeg
#   inflating: images/val/3865.jpeg
#   inflating: images/val/3866.jpeg
#   inflating: images/val/3867.jpeg
#   inflating: images/val/3868.jpeg
#   inflating: images/val/3869.jpeg
#   inflating: images/val/387.jpeg
#   inflating: images/val/3870.jpeg
#   inflating: images/val/3871.jpeg
#   inflating: images/val/3872.jpeg
#   inflating: images/val/3873.jpeg
#   inflating: images/val/3874.jpeg
#   inflating: images/val/3875.jpg
#   inflating: images/val/3876.jpg
#   inflating: images/val/3877.jpeg
#   inflating: images/val/3878.jpeg
#   inflating: images/val/3879.jpeg
#   inflating: images/val/388.jpeg
#   inflating: images/val/3880.jpeg
#   inflating: images/val/3881.jpeg
#   inflating: images/val/3882.jpeg
#   inflating: images/val/3883.jpeg
#   inflating: images/val/3884.jpeg
#   inflating: images/val/3885.jpeg
#   inflating: images/val/3886.jpeg
#   inflating: images/val/3887.jpg
#   inflating: images/val/3888.jpeg
#   inflating: images/val/3889.jpeg
#   inflating: images/val/389.jpeg
#   inflating: images/val/3890.jpeg
#   inflating: images/val/3891.jpeg
#   inflating: images/val/3892.jpeg
#   inflating: images/val/3893.jpeg
#   inflating: images/val/3894.jpg
#   inflating: images/val/3895.jpg
#   inflating: images/val/3896.jpeg
#   inflating: images/val/3897.jpeg
#   inflating: images/val/3898.jpeg
#   inflating: images/val/3899.jpeg
#   inflating: images/val/39.jpeg
#   inflating: images/val/390.jpeg
#   inflating: images/val/3900.jpeg
#   inflating: images/val/3901.jpg
#   inflating: images/val/3902.jpeg
#   inflating: images/val/3903.jpeg
#   inflating: images/val/3904.jpeg
#   inflating: images/val/3905.jpeg
#   inflating: images/val/3906.jpeg
#   inflating: images/val/3907.jpeg
#   inflating: images/val/3908.jpg
#   inflating: images/val/3909.jpeg
#   inflating: images/val/391.jpeg
#   inflating: images/val/3910.jpeg
#   inflating: images/val/3911.jpeg
#   inflating: images/val/3912.jpg
#   inflating: images/val/3913.jpeg
#   inflating: images/val/3914.jpeg
#   inflating: images/val/3915.jpg
#   inflating: images/val/3916.jpeg
#   inflating: images/val/3917.jpeg
#   inflating: images/val/3918.jpeg
#   inflating: images/val/3919.jpeg
#   inflating: images/val/392.jpeg
#   inflating: images/val/3920.jpeg
#   inflating: images/val/3921.jpeg
#   inflating: images/val/3922.jpeg
#   inflating: images/val/3923.jpeg
#   inflating: images/val/3924.jpeg
#   inflating: images/val/3925.jpeg
#   inflating: images/val/3926.jpeg
#   inflating: images/val/3927.jpeg
#   inflating: images/val/3928.jpg
#   inflating: images/val/3929.jpeg
#   inflating: images/val/393.jpeg
#   inflating: images/val/3930.jpeg
#   inflating: images/val/3931.jpeg
#   inflating: images/val/3932.jpeg
#   inflating: images/val/3933.jpg
#   inflating: images/val/3934.jpeg
#   inflating: images/val/3935.jpeg
#   inflating: images/val/3936.jpeg
#   inflating: images/val/3937.jpeg
#   inflating: images/val/3938.jpeg
#   inflating: images/val/3939.jpg
#   inflating: images/val/394.jpeg
#   inflating: images/val/3940.jpg
#   inflating: images/val/3941.jpeg
#   inflating: images/val/3942.jpg
#   inflating: images/val/3943.jpg
#   inflating: images/val/3944.jpeg
#   inflating: images/val/3945.jpeg
#   inflating: images/val/3946.jpg
#   inflating: images/val/3947.jpeg
#   inflating: images/val/3948.jpg
#   inflating: images/val/3949.jpg
#   inflating: images/val/395.jpeg
#   inflating: images/val/3950.jpeg
#   inflating: images/val/3951.jpg
#   inflating: images/val/3952.jpg
#   inflating: images/val/3953.jpeg
#   inflating: images/val/3954.jpg
#   inflating: images/val/3955.jpeg
#   inflating: images/val/3956.jpeg
#   inflating: images/val/3957.jpeg
#   inflating: images/val/3958.jpeg
#   inflating: images/val/3959.jpeg
#   inflating: images/val/396.jpeg
#   inflating: images/val/3960.jpeg
#   inflating: images/val/3961.jpeg
#   inflating: images/val/3962.jpeg
#   inflating: images/val/3963.jpg
#   inflating: images/val/3964.jpeg
#   inflating: images/val/3965.jpeg
#   inflating: images/val/3966.jpg
#   inflating: images/val/3967.jpeg
#   inflating: images/val/3968.jpeg
#   inflating: images/val/3969.jpeg
#   inflating: images/val/397.jpeg
#   inflating: images/val/3970.jpg
#   inflating: images/val/3971.jpeg
#   inflating: images/val/3972.jpeg
#   inflating: images/val/3973.jpeg
#   inflating: images/val/3974.jpeg
#   inflating: images/val/3975.jpg
#   inflating: images/val/3976.jpeg
#   inflating: images/val/3977.jpeg
#   inflating: images/val/3978.jpeg
#   inflating: images/val/3979.jpeg
#   inflating: images/val/398.jpeg
#   inflating: images/val/3980.jpeg
#   inflating: images/val/3981.jpg
#   inflating: images/val/3982.jpg
#   inflating: images/val/3983.jpeg
#   inflating: images/val/3984.jpeg
#   inflating: images/val/3985.jpeg
#   inflating: images/val/3986.jpeg
#   inflating: images/val/3987.jpeg
#   inflating: images/val/3988.jpg
#   inflating: images/val/3989.jpeg
#   inflating: images/val/399.jpeg
#   inflating: images/val/3990.jpeg
#   inflating: images/val/3991.jpg
#   inflating: images/val/3992.jpeg
#   inflating: images/val/3993.jpeg
#   inflating: images/val/3994.png
#   inflating: images/val/3995.jpeg
#   inflating: images/val/3996.jpeg
#   inflating: images/val/3997.jpeg
#   inflating: images/val/3998.jpeg
#   inflating: images/val/3999.jpg
#   inflating: images/val/4.jpeg
#   inflating: images/val/40.jpeg
#   inflating: images/val/400.jpeg
#   inflating: images/val/4000.jpeg
#   inflating: images/val/4001.jpeg
#   inflating: images/val/4002.jpeg
#   inflating: images/val/4003.jpeg
#   inflating: images/val/4004.jpeg
#   inflating: images/val/4005.jpeg
#   inflating: images/val/4006.jpeg
#   inflating: images/val/4007.jpeg
#   inflating: images/val/4008.jpeg
#   inflating: images/val/4009.jpeg
#   inflating: images/val/401.jpeg
#   inflating: images/val/4010.jpeg
#   inflating: images/val/4011.jpeg
#   inflating: images/val/4012.jpeg
#   inflating: images/val/4013.jpeg
#   inflating: images/val/4014.jpeg
#   inflating: images/val/4015.jpeg
#   inflating: images/val/4016.jpeg
#   inflating: images/val/4017.jpeg
#   inflating: images/val/4018.jpeg
#   inflating: images/val/4019.jpeg
#   inflating: images/val/402.jpeg
#   inflating: images/val/4020.jpeg
#   inflating: images/val/4021.jpeg
#   inflating: images/val/4022.jpeg
#   inflating: images/val/4023.jpeg
#   inflating: images/val/4024.jpeg
#   inflating: images/val/4025.jpeg
#   inflating: images/val/4026.jpeg
#   inflating: images/val/4027.jpeg
#   inflating: images/val/4028.jpeg
#   inflating: images/val/4029.jpeg
#   inflating: images/val/403.jpeg
#   inflating: images/val/4030.jpeg
#   inflating: images/val/4031.jpeg
#   inflating: images/val/4032.jpeg
#   inflating: images/val/4033.jpeg
#   inflating: images/val/4034.jpeg
#   inflating: images/val/4035.jpeg
#   inflating: images/val/4036.jpeg
#   inflating: images/val/4037.jpeg
#   inflating: images/val/4038.jpeg
#   inflating: images/val/4039.jpeg
#   inflating: images/val/404.jpeg
#   inflating: images/val/4040.jpeg
#   inflating: images/val/4041.jpeg
#   inflating: images/val/4042.jpeg
#   inflating: images/val/4043.jpeg
#   inflating: images/val/4044.jpeg
#   inflating: images/val/4045.jpeg
#   inflating: images/val/4046.jpeg
#   inflating: images/val/4047.jpeg
#   inflating: images/val/4048.jpeg
#   inflating: images/val/4049.jpeg
#   inflating: images/val/405.jpeg
#   inflating: images/val/4050.jpeg
#   inflating: images/val/4051.jpeg
#   inflating: images/val/4052.jpeg
#   inflating: images/val/4053.jpeg
#   inflating: images/val/4054.jpeg
#   inflating: images/val/4055.jpeg
#   inflating: images/val/4056.jpeg
#   inflating: images/val/4057.jpeg
#   inflating: images/val/4058.jpeg
#   inflating: images/val/4059.jpeg
#   inflating: images/val/406.jpeg
#   inflating: images/val/4060.jpeg
#   inflating: images/val/4061.jpeg
#   inflating: images/val/4062.jpeg
#   inflating: images/val/4063.jpeg
#   inflating: images/val/4064.jpeg
#   inflating: images/val/4065.jpeg
#   inflating: images/val/4066.jpeg
#   inflating: images/val/4067.jpeg
#   inflating: images/val/4068.jpeg
#   inflating: images/val/4069.jpeg
#   inflating: images/val/407.jpeg
#   inflating: images/val/4070.jpeg
#   inflating: images/val/4071.jpeg
#   inflating: images/val/4072.jpeg
#   inflating: images/val/4073.jpeg
#   inflating: images/val/4074.jpeg
#   inflating: images/val/4075.jpeg
#   inflating: images/val/4076.jpeg
#   inflating: images/val/4077.jpeg
#   inflating: images/val/4078.jpeg
#   inflating: images/val/4079.jpeg
#   inflating: images/val/408.jpeg
#   inflating: images/val/4080.jpeg
#   inflating: images/val/4081.jpeg
#   inflating: images/val/4082.jpeg
#   inflating: images/val/4083.jpeg
#   inflating: images/val/4084.jpeg
#   inflating: images/val/4085.jpeg
#   inflating: images/val/4086.jpeg
#   inflating: images/val/4087.jpeg
#   inflating: images/val/4088.jpeg
#   inflating: images/val/4089.jpeg
#   inflating: images/val/409.jpeg
#   inflating: images/val/4090.jpeg
#   inflating: images/val/4091.jpeg
#   inflating: images/val/4092.jpeg
#   inflating: images/val/4093.jpeg
#   inflating: images/val/4094.jpeg
#   inflating: images/val/4095.jpeg
#   inflating: images/val/4096.jpeg
#   inflating: images/val/4097.jpeg
#   inflating: images/val/4098.jpeg
#   inflating: images/val/4099.jpeg
#   inflating: images/val/41.jpeg
#   inflating: images/val/410.jpeg
#   inflating: images/val/4100.jpeg
#   inflating: images/val/4101.jpeg
#   inflating: images/val/4102.jpeg
#   inflating: images/val/4103.jpeg
#   inflating: images/val/4104.jpeg
#   inflating: images/val/4105.jpeg
#   inflating: images/val/4106.jpeg
#   inflating: images/val/4107.jpeg
#   inflating: images/val/4108.jpeg
#   inflating: images/val/4109.jpeg
#   inflating: images/val/411.jpeg
#   inflating: images/val/4110.jpeg
#   inflating: images/val/4111.jpeg
#   inflating: images/val/4112.jpeg
#   inflating: images/val/4113.jpeg
#   inflating: images/val/4114.jpeg
#   inflating: images/val/4115.jpeg
#   inflating: images/val/4116.jpeg
#   inflating: images/val/4117.jpeg
#   inflating: images/val/4118.jpeg
#   inflating: images/val/4119.jpeg
#   inflating: images/val/412.jpeg
#   inflating: images/val/4120.jpeg
#   inflating: images/val/4121.jpeg
#   inflating: images/val/4122.jpeg
#   inflating: images/val/4123.jpeg
#   inflating: images/val/4124.jpeg
#   inflating: images/val/4125.jpeg
#   inflating: images/val/4126.jpeg
#   inflating: images/val/4127.jpeg
#   inflating: images/val/4128.jpeg
#   inflating: images/val/4129.jpeg
#   inflating: images/val/413.jpeg
#   inflating: images/val/4130.jpeg
#   inflating: images/val/4131.jpeg
#   inflating: images/val/4132.jpeg
#   inflating: images/val/4133.jpeg
#   inflating: images/val/4134.jpeg
#   inflating: images/val/4135.jpeg
#   inflating: images/val/4136.jpeg
#   inflating: images/val/4137.jpeg
#   inflating: images/val/4138.jpeg
#   inflating: images/val/4139.jpeg
#   inflating: images/val/414.jpeg
#   inflating: images/val/4140.jpeg
#   inflating: images/val/4141.jpeg
#   inflating: images/val/4142.jpeg
#   inflating: images/val/4143.jpeg
#   inflating: images/val/4144.jpeg
#   inflating: images/val/4145.jpeg
#   inflating: images/val/4146.jpeg
#   inflating: images/val/4147.jpeg
#   inflating: images/val/4148.jpeg
#   inflating: images/val/4149.jpeg
#   inflating: images/val/415.jpeg
#   inflating: images/val/4150.jpeg
#   inflating: images/val/4151.jpeg
#   inflating: images/val/4152.jpeg
#   inflating: images/val/4153.jpeg
#   inflating: images/val/4154.jpeg
#   inflating: images/val/4155.jpeg
#   inflating: images/val/4156.jpeg
#   inflating: images/val/4157.jpeg
#   inflating: images/val/4158.jpeg
#   inflating: images/val/4159.jpeg
#   inflating: images/val/416.jpeg
#   inflating: images/val/4160.jpeg
#   inflating: images/val/4161.jpeg
#   inflating: images/val/4162.jpeg
#   inflating: images/val/4163.jpeg
#   inflating: images/val/4164.jpeg
#   inflating: images/val/4165.jpeg
#   inflating: images/val/4166.jpeg
#   inflating: images/val/4167.jpeg
#   inflating: images/val/4168.jpeg
#   inflating: images/val/4169.jpeg
#   inflating: images/val/417.jpeg
#   inflating: images/val/4170.jpeg
#   inflating: images/val/4171.jpeg
#   inflating: images/val/4172.jpeg
#   inflating: images/val/4173.jpeg
#   inflating: images/val/4174.jpeg
#   inflating: images/val/4175.jpeg
#   inflating: images/val/4176.jpeg
#   inflating: images/val/4177.jpeg
#   inflating: images/val/4178.jpeg
#   inflating: images/val/4179.jpeg
#   inflating: images/val/418.jpeg
#   inflating: images/val/4180.jpeg
#   inflating: images/val/4181.jpeg
#   inflating: images/val/4182.jpeg
#   inflating: images/val/4183.jpeg
#   inflating: images/val/4184.jpeg
#   inflating: images/val/4185.jpeg
#   inflating: images/val/4186.jpeg
#   inflating: images/val/4187.jpeg
#   inflating: images/val/4188.jpeg
#   inflating: images/val/4189.jpeg
#   inflating: images/val/419.jpeg
#   inflating: images/val/4190.jpeg
#   inflating: images/val/4191.jpeg
#   inflating: images/val/4192.jpeg
#   inflating: images/val/4193.jpeg
#   inflating: images/val/4194.jpeg
#   inflating: images/val/4195.jpeg
#   inflating: images/val/4196.jpeg
#   inflating: images/val/4197.jpeg
#   inflating: images/val/4198.jpeg
#   inflating: images/val/4199.jpeg
#   inflating: images/val/42.jpeg
#   inflating: images/val/420.jpeg
#   inflating: images/val/4200.jpeg
#   inflating: images/val/4201.jpeg
#   inflating: images/val/4202.jpeg
#   inflating: images/val/4203.jpeg
#   inflating: images/val/4204.jpeg
#   inflating: images/val/4205.jpeg
#   inflating: images/val/4206.jpeg
#   inflating: images/val/4207.jpeg
#   inflating: images/val/4208.jpeg
#   inflating: images/val/4209.jpeg
#   inflating: images/val/421.jpeg
#   inflating: images/val/4210.jpeg
#   inflating: images/val/4211.jpeg
#   inflating: images/val/4212.jpeg
#   inflating: images/val/4213.jpeg
#   inflating: images/val/4214.jpeg
#   inflating: images/val/4215.jpeg
#   inflating: images/val/4216.jpeg
#   inflating: images/val/4217.jpeg
#   inflating: images/val/4218.jpeg
#   inflating: images/val/4219.jpeg
#   inflating: images/val/422.jpeg
#   inflating: images/val/4220.jpeg
#   inflating: images/val/4221.jpeg
#   inflating: images/val/4222.jpeg
#   inflating: images/val/4223.jpeg
#   inflating: images/val/4224.jpeg
#   inflating: images/val/4225.jpeg
#   inflating: images/val/4226.jpeg
#   inflating: images/val/4227.jpeg
#   inflating: images/val/4228.jpeg
#   inflating: images/val/4229.jpeg
#   inflating: images/val/423.jpeg
#   inflating: images/val/4230.jpeg
#   inflating: images/val/4231.jpeg
#   inflating: images/val/4232.jpeg
#   inflating: images/val/4233.jpeg
#   inflating: images/val/4234.jpeg
#   inflating: images/val/4235.jpeg
#   inflating: images/val/4236.jpeg
#   inflating: images/val/4237.jpeg
#   inflating: images/val/4238.jpeg
#   inflating: images/val/4239.jpeg
#   inflating: images/val/424.jpeg
#   inflating: images/val/4240.jpeg
#   inflating: images/val/4241.jpeg
#   inflating: images/val/4242.jpeg
#   inflating: images/val/4243.jpeg
#   inflating: images/val/4244.jpeg
#   inflating: images/val/4245.jpeg
#   inflating: images/val/4246.jpeg
#   inflating: images/val/4247.jpeg
#   inflating: images/val/4248.jpeg
#   inflating: images/val/4249.jpeg
#   inflating: images/val/425.jpeg
#   inflating: images/val/4250.jpeg
#   inflating: images/val/4251.jpeg
#   inflating: images/val/4252.jpeg
#   inflating: images/val/4253.jpeg
#   inflating: images/val/4254.jpeg
#   inflating: images/val/4255.jpeg
#   inflating: images/val/4256.jpeg
#   inflating: images/val/4257.jpeg
#   inflating: images/val/4258.jpeg
#   inflating: images/val/4259.jpeg
#   inflating: images/val/426.jpeg
#   inflating: images/val/4260.jpeg
#   inflating: images/val/4261.jpeg
#   inflating: images/val/4262.jpeg
#   inflating: images/val/4263.jpeg
#   inflating: images/val/4264.jpeg
#   inflating: images/val/4265.jpeg
#   inflating: images/val/4266.jpeg
#   inflating: images/val/4267.jpeg
#   inflating: images/val/4268.jpeg
#   inflating: images/val/4269.jpeg
#   inflating: images/val/427.jpeg
#   inflating: images/val/4270.jpeg
#   inflating: images/val/4271.jpeg
#   inflating: images/val/4272.jpeg
#   inflating: images/val/4273.jpeg
#   inflating: images/val/4274.jpeg
#   inflating: images/val/4275.jpeg
#   inflating: images/val/4276.jpeg
#   inflating: images/val/4277.jpeg
#   inflating: images/val/4278.jpeg
#   inflating: images/val/4279.jpeg
#   inflating: images/val/428.jpeg
#   inflating: images/val/4280.jpeg
#   inflating: images/val/4281.jpeg
#   inflating: images/val/4282.jpeg
#   inflating: images/val/4283.jpeg
#   inflating: images/val/4284.jpeg
#   inflating: images/val/4285.jpeg
#   inflating: images/val/4286.jpeg
#   inflating: images/val/4287.jpeg
#   inflating: images/val/4288.jpeg
#   inflating: images/val/4289.jpeg
#   inflating: images/val/429.jpeg
#   inflating: images/val/4290.jpeg
#   inflating: images/val/4291.jpeg
#   inflating: images/val/4292.jpeg
#   inflating: images/val/4293.jpeg
#   inflating: images/val/4294.jpeg
#   inflating: images/val/4295.jpeg
#   inflating: images/val/4296.jpeg
#   inflating: images/val/4297.jpeg
#   inflating: images/val/4298.jpeg
#   inflating: images/val/4299.jpeg
#   inflating: images/val/43.jpeg
#   inflating: images/val/430.jpeg
#   inflating: images/val/4300.jpeg
#   inflating: images/val/4301.jpeg
#   inflating: images/val/4302.jpeg
#   inflating: images/val/4303.jpeg
#   inflating: images/val/4304.jpeg
#   inflating: images/val/4305.jpeg
#   inflating: images/val/4306.jpeg
#   inflating: images/val/4307.jpeg
#   inflating: images/val/4308.jpeg
#   inflating: images/val/4309.jpeg
#   inflating: images/val/431.jpeg
#   inflating: images/val/4310.jpeg
#   inflating: images/val/4311.jpeg
#   inflating: images/val/4312.jpeg
#   inflating: images/val/4313.jpeg
#   inflating: images/val/4314.jpeg
#   inflating: images/val/4315.jpeg
#   inflating: images/val/4316.jpeg
#   inflating: images/val/4317.jpeg
#   inflating: images/val/4318.jpeg
#   inflating: images/val/4319.jpeg
#   inflating: images/val/432.jpeg
#   inflating: images/val/4320.jpeg
#   inflating: images/val/4321.jpeg
#   inflating: images/val/4322.jpeg
#   inflating: images/val/4323.jpeg
#   inflating: images/val/4324.jpeg
#   inflating: images/val/4325.jpeg
#   inflating: images/val/4326.jpeg
#   inflating: images/val/4327.jpeg
#   inflating: images/val/4328.jpeg
#   inflating: images/val/4329.jpeg
#   inflating: images/val/433.jpeg
#   inflating: images/val/4330.jpeg
#   inflating: images/val/4331.jpeg
#   inflating: images/val/4332.jpeg
#   inflating: images/val/4333.jpeg
#   inflating: images/val/4334.jpeg
#   inflating: images/val/4335.jpeg
#   inflating: images/val/4336.jpeg
#   inflating: images/val/4337.jpeg
#   inflating: images/val/4338.jpeg
#   inflating: images/val/4339.jpeg
#   inflating: images/val/434.jpeg
#   inflating: images/val/4340.jpeg
#   inflating: images/val/4341.jpeg
#   inflating: images/val/4342.jpeg
#   inflating: images/val/4343.jpeg
#   inflating: images/val/4344.jpeg
#   inflating: images/val/4345.jpeg
#   inflating: images/val/4346.jpeg
#   inflating: images/val/4347.jpeg
#   inflating: images/val/4348.jpeg
#   inflating: images/val/4349.jpeg
#   inflating: images/val/435.jpeg
#   inflating: images/val/4350.jpeg
#   inflating: images/val/4351.jpeg
#   inflating: images/val/4352.jpeg
#   inflating: images/val/4353.jpeg
#   inflating: images/val/4354.jpeg
#   inflating: images/val/4355.jpeg
#   inflating: images/val/4356.jpeg
#   inflating: images/val/4357.jpeg
#   inflating: images/val/4358.jpeg
#   inflating: images/val/4359.jpeg
#   inflating: images/val/436.jpeg
#   inflating: images/val/4360.jpeg
#   inflating: images/val/4361.jpeg
#   inflating: images/val/4362.jpeg
#   inflating: images/val/4363.jpeg
#   inflating: images/val/4364.jpeg
#   inflating: images/val/4365.jpeg
#   inflating: images/val/4366.jpeg
#   inflating: images/val/4367.jpeg
#   inflating: images/val/4368.jpeg
#   inflating: images/val/4369.jpeg
#   inflating: images/val/437.jpeg
#   inflating: images/val/4370.jpeg
#   inflating: images/val/4371.jpeg
#   inflating: images/val/4372.jpeg
#   inflating: images/val/4373.jpeg
#   inflating: images/val/4374.jpeg
#   inflating: images/val/4375.jpeg
#   inflating: images/val/4376.jpeg
#   inflating: images/val/4377.jpeg
#   inflating: images/val/4378.jpeg
#   inflating: images/val/4379.jpeg
#   inflating: images/val/438.jpeg
#   inflating: images/val/4380.jpeg
#   inflating: images/val/4381.jpeg
#   inflating: images/val/4382.jpeg
#   inflating: images/val/4383.jpeg
#   inflating: images/val/4384.jpeg
#   inflating: images/val/4385.jpeg
# ...
#   inflating: images/val/7372.jpeg
#   inflating: images/val/7373.jpeg
#   inflating: images/val/7374.jpeg
#   inflating: images/val/7375.jpeg
#   inflating: images/val/7376.jpeg
#   inflating: images/val/7377.jpeg
#   inflating: images/val/7378.jpeg
#   inflating: images/val/7379.jpeg
#   inflating: images/val/738.jpeg
#   inflating: images/val/7380.jpeg
#   inflating: images/val/7381.jpeg
#   inflating: images/val/7382.jpeg
#   inflating: images/val/7383.jpeg
#   inflating: images/val/7384.jpeg
#   inflating: images/val/7385.jpeg
#   inflating: images/val/7386.jpeg
#   inflating: images/val/7387.jpeg
#   inflating: images/val/7388.jpeg
#   inflating: images/val/7389.jpeg
#   inflating: images/val/739.jpeg
#   inflating: images/val/7390.jpeg
#   inflating: images/val/7391.jpeg
#   inflating: images/val/7392.jpeg
#   inflating: images/val/7393.jpeg
#   inflating: images/val/7394.jpeg
#   inflating: images/val/7395.jpeg
#   inflating: images/val/7396.jpeg
#   inflating: images/val/7397.jpeg
#   inflating: images/val/7398.jpeg
#   inflating: images/val/7399.jpeg
#   inflating: images/val/74.jpeg
#   inflating: images/val/740.jpeg
#   inflating: images/val/7400.jpeg
#   inflating: images/val/7401.jpeg
#   inflating: images/val/7402.jpeg
#   inflating: images/val/7403.jpeg
#   inflating: images/val/7404.jpeg
#   inflating: images/val/7405.jpeg
#   inflating: images/val/7406.jpeg
#   inflating: images/val/7407.jpeg
#   inflating: images/val/7408.jpeg
#   inflating: images/val/7409.jpeg
#   inflating: images/val/741.jpeg
#   inflating: images/val/7410.jpeg
#   inflating: images/val/7411.jpeg
#   inflating: images/val/7412.jpeg
#   inflating: images/val/7413.jpeg
#   inflating: images/val/7414.jpeg
#   inflating: images/val/7415.jpeg
#   inflating: images/val/7416.jpeg
#   inflating: images/val/7417.jpeg
#   inflating: images/val/7418.jpeg
#   inflating: images/val/7419.jpeg
#   inflating: images/val/742.jpeg
#   inflating: images/val/7420.jpeg
#   inflating: images/val/7421.jpeg
#   inflating: images/val/7422.jpeg
#   inflating: images/val/7423.jpeg
#   inflating: images/val/7424.jpeg
#   inflating: images/val/7425.jpeg
#   inflating: images/val/7426.jpeg
#   inflating: images/val/7427.jpeg
#   inflating: images/val/7428.jpeg
#   inflating: images/val/7429.jpeg
#   inflating: images/val/743.jpeg
#   inflating: images/val/7430.jpeg
#   inflating: images/val/7431.jpeg
#   inflating: images/val/7432.jpeg
#   inflating: images/val/7433.jpeg
#   inflating: images/val/7434.jpeg
#   inflating: images/val/7435.jpeg
#   inflating: images/val/7436.jpeg
#   inflating: images/val/7437.jpeg
#   inflating: images/val/7438.jpeg
#   inflating: images/val/7439.jpeg
#   inflating: images/val/744.jpeg
#   inflating: images/val/7440.jpeg
#   inflating: images/val/7441.jpeg
#   inflating: images/val/7442.jpeg
#   inflating: images/val/7443.jpeg
#   inflating: images/val/7444.jpeg
#   inflating: images/val/7445.jpeg
#   inflating: images/val/7446.jpeg
#   inflating: images/val/7447.jpeg
#   inflating: images/val/7448.jpeg
#   inflating: images/val/7449.jpeg
#   inflating: images/val/745.jpeg
#   inflating: images/val/7450.jpeg
#   inflating: images/val/7451.jpeg
#   inflating: images/val/7452.jpeg
#   inflating: images/val/7453.jpeg
#   inflating: images/val/7454.jpeg
#   inflating: images/val/7455.jpeg
#   inflating: images/val/7456.jpeg
#   inflating: images/val/7457.jpeg
#   inflating: images/val/7458.jpeg
#   inflating: images/val/7459.jpeg
#   inflating: images/val/746.jpeg
#   inflating: images/val/7460.jpeg
#   inflating: images/val/7461.jpeg
#   inflating: images/val/7462.jpeg
#   inflating: images/val/7463.jpeg
#   inflating: images/val/7464.jpeg
#   inflating: images/val/7465.jpeg
#   inflating: images/val/7466.jpeg
#   inflating: images/val/7467.jpeg
#   inflating: images/val/7468.jpeg
#   inflating: images/val/7469.jpeg
#   inflating: images/val/747.jpeg
#   inflating: images/val/7470.jpeg
#   inflating: images/val/7471.jpeg
#   inflating: images/val/7472.jpeg
#   inflating: images/val/7473.jpeg
#   inflating: images/val/7474.jpeg
#   inflating: images/val/7475.jpeg
#   inflating: images/val/7476.jpeg
#   inflating: images/val/7477.jpeg
#   inflating: images/val/7478.jpeg
#   inflating: images/val/7479.jpeg
#   inflating: images/val/748.jpeg
#   inflating: images/val/7480.jpeg
#   inflating: images/val/7481.jpeg
#   inflating: images/val/7482.jpeg
#   inflating: images/val/7483.jpeg
#   inflating: images/val/7484.jpeg
#   inflating: images/val/7485.jpeg
#   inflating: images/val/7486.jpeg
#   inflating: images/val/7487.jpeg
#   inflating: images/val/7488.jpeg
#   inflating: images/val/7489.jpeg
#   inflating: images/val/749.jpeg
#   inflating: images/val/7490.jpeg
#   inflating: images/val/7491.jpeg
#   inflating: images/val/7492.jpeg
#   inflating: images/val/7493.jpeg
#   inflating: images/val/7494.jpeg
#   inflating: images/val/7495.jpeg
#   inflating: images/val/7496.jpeg
#   inflating: images/val/7497.jpeg
#   inflating: images/val/7498.jpeg
#   inflating: images/val/7499.jpeg
#   inflating: images/val/75.jpeg
#   inflating: images/val/750.jpeg
#   inflating: images/val/751.jpeg
#   inflating: images/val/752.jpeg
#   inflating: images/val/753.jpeg
#   inflating: images/val/754.jpeg
#   inflating: images/val/755.jpeg
#   inflating: images/val/756.jpeg
#   inflating: images/val/757.jpeg
#   inflating: images/val/758.jpeg
#   inflating: images/val/759.jpeg
#   inflating: images/val/76.jpeg
#   inflating: images/val/760.jpeg
#   inflating: images/val/761.jpeg
#   inflating: images/val/762.jpeg
#   inflating: images/val/763.jpeg
#   inflating: images/val/764.jpeg
#   inflating: images/val/765.jpeg
#   inflating: images/val/766.jpeg
#   inflating: images/val/767.jpeg
#   inflating: images/val/768.jpeg
#   inflating: images/val/769.jpeg
#   inflating: images/val/77.jpeg
#   inflating: images/val/770.jpeg
#   inflating: images/val/771.jpeg
#   inflating: images/val/772.jpeg
#   inflating: images/val/773.jpeg
#   inflating: images/val/774.jpeg
#   inflating: images/val/775.jpeg
#   inflating: images/val/776.jpeg
#   inflating: images/val/777.jpeg
#   inflating: images/val/778.jpeg
#   inflating: images/val/779.jpeg
#   inflating: images/val/78.jpeg
#   inflating: images/val/780.jpeg
#   inflating: images/val/781.jpeg
#   inflating: images/val/782.jpeg
#   inflating: images/val/783.jpeg
#   inflating: images/val/784.jpeg
#   inflating: images/val/785.jpeg
#   inflating: images/val/786.jpeg
#   inflating: images/val/787.jpeg
#   inflating: images/val/788.jpeg
#   inflating: images/val/789.jpeg
#   inflating: images/val/79.jpeg
#   inflating: images/val/790.jpeg
#   inflating: images/val/791.jpeg
#   inflating: images/val/792.jpeg
#   inflating: images/val/793.jpeg
#   inflating: images/val/794.jpeg
#   inflating: images/val/795.jpeg
#   inflating: images/val/796.jpeg
#   inflating: images/val/797.jpeg
#   inflating: images/val/798.jpeg
#   inflating: images/val/799.jpeg
#   inflating: images/val/8.jpeg
#   inflating: images/val/80.jpeg
#   inflating: images/val/800.jpeg
#   inflating: images/val/801.jpeg
#   inflating: images/val/802.jpeg
#   inflating: images/val/803.jpeg
#   inflating: images/val/804.jpeg
#   inflating: images/val/805.jpeg
#   inflating: images/val/806.jpeg
#   inflating: images/val/807.jpeg
#   inflating: images/val/808.jpeg
#   inflating: images/val/809.jpeg
#   inflating: images/val/81.jpeg
#   inflating: images/val/810.jpeg
#   inflating: images/val/811.jpeg
#   inflating: images/val/812.jpeg
#   inflating: images/val/813.jpeg
#   inflating: images/val/814.jpeg
#   inflating: images/val/815.jpeg
#   inflating: images/val/816.jpeg
#   inflating: images/val/817.jpeg
#   inflating: images/val/818.jpeg
#   inflating: images/val/819.jpeg
#   inflating: images/val/82.jpeg
#   inflating: images/val/820.jpeg
#   inflating: images/val/821.jpeg
#   inflating: images/val/822.jpeg
#   inflating: images/val/823.jpeg
#   inflating: images/val/824.jpeg
#   inflating: images/val/825.jpeg
#   inflating: images/val/826.jpeg
#   inflating: images/val/827.jpeg
#   inflating: images/val/828.jpeg
#   inflating: images/val/829.jpeg
#   inflating: images/val/83.jpeg
#   inflating: images/val/830.jpeg
#   inflating: images/val/831.jpeg
#   inflating: images/val/832.jpeg
#   inflating: images/val/833.jpeg
#   inflating: images/val/834.jpeg
#   inflating: images/val/835.jpeg
#   inflating: images/val/836.jpeg
#   inflating: images/val/837.jpeg
#   inflating: images/val/838.jpeg
#   inflating: images/val/839.jpeg
#   inflating: images/val/84.jpeg
#   inflating: images/val/840.jpeg
#   inflating: images/val/841.jpeg
#   inflating: images/val/842.jpeg
#   inflating: images/val/843.jpeg
#   inflating: images/val/844.jpeg
#   inflating: images/val/845.jpeg
#   inflating: images/val/846.jpeg
#   inflating: images/val/847.jpeg
#   inflating: images/val/848.jpeg
#   inflating: images/val/849.jpeg
#   inflating: images/val/85.jpeg
#   inflating: images/val/850.jpeg
#   inflating: images/val/851.jpeg
#   inflating: images/val/852.jpeg
#   inflating: images/val/853.jpeg
#   inflating: images/val/854.jpeg
#   inflating: images/val/855.jpeg
#   inflating: images/val/856.jpeg
#   inflating: images/val/857.jpeg
#   inflating: images/val/858.jpeg
#   inflating: images/val/859.jpeg
#   inflating: images/val/86.jpeg
#   inflating: images/val/860.jpeg
#   inflating: images/val/861.jpeg
#   inflating: images/val/862.jpeg
#   inflating: images/val/863.jpeg
#   inflating: images/val/864.jpeg
#   inflating: images/val/865.jpeg
#   inflating: images/val/866.jpeg
#   inflating: images/val/867.jpeg
#   inflating: images/val/868.jpeg
#   inflating: images/val/869.jpeg
#   inflating: images/val/87.jpeg
#   inflating: images/val/870.jpeg
#   inflating: images/val/871.jpeg
#   inflating: images/val/872.jpeg
#   inflating: images/val/873.jpeg
#   inflating: images/val/874.jpeg
#   inflating: images/val/875.jpeg
#   inflating: images/val/876.jpeg
#   inflating: images/val/877.jpeg
#   inflating: images/val/878.jpeg
#   inflating: images/val/879.jpeg
#   inflating: images/val/88.jpeg
#   inflating: images/val/880.jpeg
#   inflating: images/val/881.jpeg
#   inflating: images/val/882.jpeg
#   inflating: images/val/883.jpeg
#   inflating: images/val/884.jpeg
#   inflating: images/val/885.jpeg
#   inflating: images/val/886.jpeg
#   inflating: images/val/887.jpeg
#   inflating: images/val/888.jpeg
#   inflating: images/val/889.jpeg
#   inflating: images/val/89.jpeg
#   inflating: images/val/890.jpeg
#   inflating: images/val/891.jpeg
#   inflating: images/val/892.jpeg
#   inflating: images/val/893.jpeg
#   inflating: images/val/894.jpeg
#   inflating: images/val/895.jpeg
#   inflating: images/val/896.jpeg
#   inflating: images/val/897.jpeg
#   inflating: images/val/898.jpeg
#   inflating: images/val/899.jpeg
#   inflating: images/val/9.jpeg
#   inflating: images/val/90.jpeg
#   inflating: images/val/900.jpeg
#   inflating: images/val/901.jpeg
#   inflating: images/val/902.jpeg
#   inflating: images/val/903.jpeg
#   inflating: images/val/904.jpeg
#   inflating: images/val/905.jpeg
#   inflating: images/val/906.jpeg
#   inflating: images/val/907.jpeg
#   inflating: images/val/908.jpeg
#   inflating: images/val/909.jpeg
#   inflating: images/val/91.jpeg
#   inflating: images/val/910.jpeg
#   inflating: images/val/911.jpeg
#   inflating: images/val/912.jpeg
#   inflating: images/val/913.jpeg
#   inflating: images/val/914.jpeg
#   inflating: images/val/915.jpeg
#   inflating: images/val/916.jpeg
#   inflating: images/val/917.jpeg
#   inflating: images/val/918.jpeg
#   inflating: images/val/919.jpeg
#   inflating: images/val/92.jpeg
#   inflating: images/val/920.jpeg
#   inflating: images/val/921.jpeg
#   inflating: images/val/922.jpeg
#   inflating: images/val/923.jpeg
#   inflating: images/val/924.jpeg
#   inflating: images/val/925.jpeg
#   inflating: images/val/926.jpeg
#   inflating: images/val/927.jpeg
#   inflating: images/val/928.jpeg
#   inflating: images/val/929.jpeg
#   inflating: images/val/93.jpeg
#   inflating: images/val/930.jpeg
#   inflating: images/val/931.jpeg
#   inflating: images/val/932.jpeg
#   inflating: images/val/933.jpeg
#   inflating: images/val/934.jpeg
#   inflating: images/val/935.jpeg
#   inflating: images/val/936.jpeg
#   inflating: images/val/937.jpeg
#   inflating: images/val/938.jpeg
#   inflating: images/val/939.jpeg
#   inflating: images/val/94.jpeg
#   inflating: images/val/940.jpeg
#   inflating: images/val/941.jpeg
#   inflating: images/val/942.jpeg
#   inflating: images/val/943.jpeg
#   inflating: images/val/944.jpeg
#   inflating: images/val/945.jpeg
#   inflating: images/val/946.jpeg
#   inflating: images/val/947.jpeg
#   inflating: images/val/948.jpeg
#   inflating: images/val/949.jpeg
#   inflating: images/val/95.jpeg
#   inflating: images/val/950.jpeg
#   inflating: images/val/951.jpeg
#   inflating: images/val/952.jpeg
#   inflating: images/val/953.jpeg
#   inflating: images/val/954.jpeg
#   inflating: images/val/955.jpeg
#   inflating: images/val/956.jpeg
#   inflating: images/val/957.jpeg
#   inflating: images/val/958.jpeg
#   inflating: images/val/959.jpeg
#   inflating: images/val/96.jpeg
#   inflating: images/val/960.jpeg
#   inflating: images/val/961.jpeg
#   inflating: images/val/962.jpeg
#   inflating: images/val/963.jpeg
#   inflating: images/val/964.jpeg
#   inflating: images/val/965.jpeg
#   inflating: images/val/966.jpeg
#   inflating: images/val/967.jpeg
#   inflating: images/val/968.jpeg
#   inflating: images/val/969.jpeg
#   inflating: images/val/97.jpeg
#   inflating: images/val/970.jpeg
#   inflating: images/val/971.jpeg
#   inflating: images/val/972.jpeg
#   inflating: images/val/973.jpeg
#   inflating: images/val/974.jpeg
#   inflating: images/val/975.jpeg
#   inflating: images/val/976.jpeg
#   inflating: images/val/977.jpeg
#   inflating: images/val/978.jpeg
#   inflating: images/val/979.jpeg
#   inflating: images/val/98.jpeg
#   inflating: images/val/980.jpeg
#   inflating: images/val/981.jpeg
#   inflating: images/val/982.jpeg
#   inflating: images/val/983.jpeg
#   inflating: images/val/984.jpeg
#   inflating: images/val/985.jpeg
#   inflating: images/val/986.jpeg
#   inflating: images/val/987.jpeg
#   inflating: images/val/988.jpeg
#   inflating: images/val/989.jpeg
#   inflating: images/val/99.jpeg
#   inflating: images/val/990.jpeg
#   inflating: images/val/991.jpeg
#   inflating: images/val/992.jpeg
#   inflating: images/val/993.jpeg
#   inflating: images/val/994.jpeg
#   inflating: images/val/995.jpeg
#   inflating: images/val/996.jpeg
#   inflating: images/val/997.jpeg
#   inflating: images/val/998.jpeg
#   inflating: images/val/999.jpeg
#   inflating: test_data.json
#   inflating: train_data.json
#   inflating: val_data.json

# %%
from PIL import Image
import os

# Specify the directory containing the JPEG files
jpeg_directory = '/content/drive/MyDrive/Colab Notebooks/transformer_learn/Kaggle/images/train'

# Iterate over all files in the directory
for filename in os.listdir(jpeg_directory):
    # Check if the file has a JPEG extension
    if filename.lower().endswith('.jpg') or filename.lower().endswith('.jpeg'):
        # Construct the full path to the JPEG file
        jpeg_file_path = os.path.join(jpeg_directory, filename)

        # Open the JPEG file
        with Image.open(jpeg_file_path) as image:
            # Construct the full path to the PNG file
            png_file_path = os.path.join(jpeg_directory, filename.rsplit('.', 1)[0] + '.png')

            # Save the image in PNG format
            image.save(png_file_path, 'PNG')

        # Delete the original JPEG file
        os.remove(jpeg_file_path)

# %%
# !pip install datasets
# !pip install diffusers
# !pip install accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 26.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.2 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.9 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 20.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diffusers
#   Downloading diffusers-0.16.1-py3-none-any.whl (934 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.9/934.9 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.12.0)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.14.1)
# Collecting importlib-metadata (from diffusers)
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.27.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (2023.4.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (23.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4)
# Installing collected packages: importlib-metadata, diffusers
# Successfully installed diffusers-0.16.1 importlib-metadata-6.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.19.0

# %% [markdown]
# # Declare TrainingArguments
# 1. `dataclass`: dataclass is a decorator introduced in Python 3.7 that simplifies the process of creating classes used mainly for storing data.
# 2. mixed_precision:
#   *  Speed up training and reduce memory requirements without significantly affecting model accuracy.
#   * The forward and backward passes of the model are typically performed using lower-precision data types
#   * The weights are updated using a single-precision data type to maintain the model's accuracy

# %%
from dataclasses import dataclass

@dataclass
class TrainingConfiguration:
    image_size = 128  # resolution of the generated images
    train_batch_size = 4
    eval_batch_size = 32  # number of images to sample during evaluation
    num_epochs = 100
    gradient_accumulation_steps = 2
    learning_rate = 2e-4
    lr_warmup_steps = 100
    save_image_epochs = 4
    save_model_epochs = 4
    mixed_precision = 'fp16'  
    output_dir = '/content/drive/MyDrive/Colab Notebooks/transformer_learn/chapter8/image_gen1'  # model name locally and on the HF Hub

    overwrite_output_dir = True  # overwrite the old model when re-running the notebook
    seed = 100

config = TrainingConfiguration()

# %%
import torch
if not torch.cuda.is_available():
    config.mixed_precision = False

# %%
config.mixed_precision
# Out:
# 'fp16'

# %% [markdown]
# # Load the Dataset
# 1. It is dog image datasets with 1104 samples

# %%
from datasets import load_dataset
dataset = load_dataset("BirdL/DALL-E-Dogs", split="train")
# Out:
# Downloading metadata:   0%|          | 0.00/769 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/562 [00:00<?, ?B/s]
# Downloading and preparing dataset None/None (download: 94.13 MiB, generated: 114.91 MiB, post-processed: Unknown size, total: 209.04 MiB) to /root/.cache/huggingface/datasets/BirdL___parquet/BirdL--DALL-E-Dogs-3fef086dc9e2e9d7/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/98.7M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1104 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/BirdL___parquet/BirdL--DALL-E-Dogs-3fef086dc9e2e9d7/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.

# %%
print(dataset)
print(dataset[0])
# Out:
# Dataset({
#     features: ['Images'],
#     num_rows: 1104
# })
# {'Images': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FBDF660DAB0>}

# %% [markdown]
# ## Let's plot few images

# %%
import matplotlib.pyplot as plt
from PIL import Image

def plot_images(images, titles=None, cols=2, figsize=(10, 5)):
    rows = len(images) // cols + int(len(images) % cols > 0)
    fig, axs = plt.subplots(rows, cols, figsize=figsize)
    axs = axs.flatten()

    for idx, img in enumerate(images):
        axs[idx].imshow(img)
        axs[idx].axis("off")
        if titles:
            axs[idx].set_title(titles[idx])

    plt.tight_layout()
    plt.show()

# Select four random images from the dataset
four_images = [dataset[i]["Images"] for i in range(4)]

plot_images(four_images)

# %% [markdown]
# # Declare Transformation
# 1. dataset class provides image mechanism of applying transformation by just calling set_transform

# %%
from torchvision import transforms

preprocess = transforms.Compose(
    [
        transforms.Resize((config.image_size, config.image_size)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(degrees=15),  # Random rotation with a maximum of 15 degrees
        transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),  # Color jitter
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]),
    ]
)

def transform(examples):
    images = [preprocess(image.convert("RGB")) for image in examples["Images"]]
    return {"image": images}

dataset.set_transform(transform)

# %% [markdown]
# ## Let's Plot the image after the transformation is applied.
# 1. Now, the image is in the form of tensor with (C,W,H). imshow requires images in the form of (W,H,C). Thus, we are doing permute(1,2,0)

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 8))
for i in range(2):
    for j in range(2):
        index = i * 2 + j
        image = dataset[index]['image'].permute(1, 2, 0).numpy() * 0.5 + 0.5  # Denormalize the image
        axes[i, j].imshow(image)
        axes[i, j].axis('off')

plt.show()

# %% [markdown]
# # Let's Declare train_loader

# %%
import torch

train_dataloader = torch.utils.data.DataLoader(dataset, batch_size=config.train_batch_size, shuffle=True)

# %% [markdown]
# # Let's Declare Unet2Model from the Diffusers.
# Let's discuss the model parameters:
#
#
# * sample_size: The size of the input images.
# * in_channels: The number of input channels (e.g., 3 for RGB images).
# * out_channels: The number of output channels (e.g., the number of classes for segmentation tasks).
# * layers_per_block: The number of layers (convolutions) within each block of the U-Net architecture.
# * block_out_channels: A tuple specifying the number of output channels for each block in the architecture.
# * down_block_types: A tuple specifying the types of downsampling blocks to use in the encoding path.
#   1. "DownBlock2D": DownBlock2D is a custom implementation of a downsampling block used in the U-Net architecture. It has, CNN, Batch Normalization, and Pooling.
#   2. "AttnDownBlock2D,"
# up_block_types: A tuple specifying the types of upsampling blocks to use in the decoding path.
#   1. "UpBlock2D"
#   2. "AttnUpBlock2D"

# %%
from diffusers import UNet2DModel

model = UNet2DModel(
    sample_size=config.image_size,
    in_channels=3,
    out_channels=3,
    layers_per_block=3,
    block_out_channels=(64, 128, 256, 512, 1024),
    down_block_types=(
        "DownBlock2D",
        "AttnDownBlock2D",
        "DownBlock2D",
        "DownBlock2D",
        "DownBlock2D",
    ),
    up_block_types=(
        "UpBlock2D",
        "UpBlock2D",
        "AttnUpBlock2D",
        "UpBlock2D",
        "UpBlock2D",
    ),
)

# %%
from diffusers import DDPMScheduler
'''
The num_train_timesteps=1000 argument specifies the total number of timesteps that will be used during the training process.
 In other words, the noise injection process will be divided into 1000 steps,
 and each step will introduce a certain amount of noise according to the model's noise schedule.
 What does this means is
  - noise will be added to the original images over 1000 steps
  - after 1000 steps, the clean image will turned into complete noise
'''
noise_scheduler = DDPMScheduler(num_train_timesteps=1000)

# %%
sample_image = dataset[0]['image'].unsqueeze(0)
import torch
from PIL import Image

noise_tensor = torch.randn(sample_image.shape)
num_timesteps = torch.LongTensor([50])
perturbed_image = noise_scheduler.add_noise(sample_image, noise_tensor, num_timesteps)

restored_image = ((perturbed_image.permute(0, 2, 3, 1) + 1.0) * 140).type(torch.uint8).numpy()[0]
output_image = Image.fromarray(restored_image)
output_image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FBD45163D90>

# %%
import torch.nn.functional as F
optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate)

# %%
from diffusers.optimization import get_cosine_schedule_with_warmup

lr_scheduler = get_cosine_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=config.lr_warmup_steps,
    num_training_steps=(len(train_dataloader) * config.num_epochs),
)

# %%
from diffusers import DDPMPipeline
import math

def create_image_grid(images, num_rows, num_cols):
    width, height = images[0].size
    grid = Image.new('RGB', size=(num_cols * width, num_rows * height))
    for idx, img in enumerate(images):
        grid.paste(img, box=(idx % num_cols * width, idx // num_cols * height))
    return grid

def perform_evaluation(updated_config, current_epoch, diffusion_pipeline):
    # Generate images from random noise (backward diffusion process).
    # The default pipeline output type is `List[PIL.Image]`
    generated_images = diffusion_pipeline(
        batch_size=updated_config.eval_batch_size,
        generator=torch.manual_seed(updated_config.seed),
    ).images

    # Create a grid from the generated images
    img_grid = create_image_grid(generated_images, num_rows=4, num_cols=4)

    # Save the images
    test_output_dir = os.path.join(updated_config.output_dir, "samples")
    os.makedirs(test_output_dir, exist_ok=True)
    img_grid.save(f"{test_output_dir}/{current_epoch:04d}.png")

# %%
import torch
import torch.nn.functional as F
from accelerate import Accelerator
from tqdm.auto import tqdm
import os

def train(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler):
    # Initialize accelerator and tensorboard logging
    accelerator = Accelerator(
        mixed_precision='no',
        gradient_accumulation_steps=config.gradient_accumulation_steps,
        log_with="tensorboard",
        logging_dir=os.path.join(config.output_dir, "logs")
    )

    if config.output_dir is not None:
        os.makedirs(config.output_dir, exist_ok=True)
        accelerator.init_trackers("train_example")

    # Prepare everything
    model, optimizer, train_dataloader, lr_scheduler = accelerator.prepare(
        model, optimizer, train_dataloader, lr_scheduler
    )

    overall_step = 0

    # Train the model
    for epoch in range(config.num_epochs):
        progress_bar = tqdm(total=len(train_dataloader), disable=not accelerator.is_local_main_process)
        progress_bar.set_description(f"Epoch {epoch}")

        for step, batch in enumerate(train_dataloader):
            # retrive the clean image
            clean_images = batch['image']
            # generate random noise with the same shape as the clean_image
            noise = torch.randn(clean_images.shape).to(clean_images.device)
            #this is just batch size
            bs = clean_images.shape[0]

            '''This generates a tensor of random integers. The integers are drawn from a discrete 
           uniform distribution in the range [0, noise_scheduler.num_train_timesteps).
            The shape of the tensor is (bs,), where bs is the batch size, meaning one timestep is generated for each image in the batch.
            These timesteps represent the stages at which noise is added during the forward diffusion process.
             For each image in the batch, a different timestep is randomly chosen,
              which means different amounts of noise will be added to each image.
            '''
            timesteps = torch.randint(0, noise_scheduler.num_train_timesteps, (bs,), device=clean_images.device).long()
            '''
            clean_images: These are the original, noise-free images that you want to corrupt with noise.
            noise:  This is a tensor of noise that you want to add to the clean images. It's typically randomly generated and has the same shape as clean_images.
            timesteps: These are the stages at which you want to add the noise.
             Each timestep corresponds to a different amount of noise according to the noise schedule. We have generated the timestamp of shape (bs,) in above line
            '''
            noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)
            '''
            config.gradient_accumulation_steps = 2
            `accelerator.accumulate(model)`  is designed to handle gradient accumulation during model training.
            The gradient are computed for each forward and backward pass but the model weight are updated based on the gradient_accumulation_steps
            This technique enable to have effective batch size larger then the batch_size chosed in trainloader
            '''
            with accelerator.accumulate(model):
                noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
                loss = F.mse_loss(noise_pred, noise)
                accelerator.backward(loss)

                accelerator.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                lr_scheduler.step()
                optimizer.zero_grad()

            progress_bar.update(1)
            logs = {"loss": loss.detach().item(), "lr": lr_scheduler.get_last_lr()[0], "step": overall_step}
            progress_bar.set_postfix(**logs)
            accelerator.log(logs, step=overall_step)
            overall_step += 1

        '''
        `if accelerator.is_main_process:` on the distributed training only the main process execute the following code. 
        This avoid redunant computation and conflict
        '''
        if accelerator.is_main_process:
          # This line initializes a DDPMPipeline object. We will use the pipeline to perform evaluation, save the generated image in that step
          #  and also we will save that pipeline
          pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)

          if (epoch + 1) % config.save_image_epochs == 0 or (epoch + 1) % config.save_model_epochs == 0 or epoch == config.num_epochs - 1:
              perform_evaluation(config, epoch, pipeline)
              pipeline.save_pretrained(config.output_dir)

# %%
train(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:258: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
#   0%|          | 0/276 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:135: FutureWarning: Accessing config attribute `num_train_timesteps` directly via 'DDPMScheduler' object attribute is deprecated. Please access 'num_train_timesteps' over 'DDPMScheduler's config object instead, e.g. 'scheduler.config.num_train_timesteps'.
#   deprecate("direct config name access", "1.0.0", deprecation_message, standard_warn=False)
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Further Training

# %%
model_path = "/content/drive/MyDrive/Colab Notebooks/transformer_learn/chapter8/image_gen/unet/diffusion_pytorch_model.bin"
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
train(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:258: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
#   0%|          | 0/276 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:135: FutureWarning: Accessing config attribute `num_train_timesteps` directly via 'DDPMScheduler' object attribute is deprecated. Please access 'num_train_timesteps' over 'DDPMScheduler's config object instead, e.g. 'scheduler.config.num_train_timesteps'.
#   deprecate("direct config name access", "1.0.0", deprecation_message, standard_warn=False)
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]

# %% [markdown]
# # Let's Use the model for Inference
# 1. Our Model is Diffusion pipeline. Thus, you need to point to the location in  your drive where you have the pipeline shaped. The directory show have
#   * model_index.json
#   * unet
#   * scheduler
#
# 2. The following code shows how to create one image or multiple images.
# 3. DDPMP pipeline is slow but produce high quality images. Here, we are using DDIMPipeline which is faster

# %%
from diffusers import DDPMPipeline, DDIMPipeline, PNDMPipeline

model_id = "/content/drive/MyDrive/Colab Notebooks/transformer_learn/chapter8/image_gen1/"

# load model and scheduler
ddim = DDIMPipeline.from_pretrained(model_id).to('cuda')  # you can replace DDPMPipeline with DDIMPipeline or PNDMPipeline for faster inference

# %%
from PIL import Image

# run pipeline in inference (sample random noise and denoise)
image = ddim().images[0]
image.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FBC71336F80>

# %%
from PIL import Image

# Generate 6 images
generated_images = ddim(batch_size=6).images

# Create a grid
num_rows = 2
num_cols = 3
width, height = generated_images[0].size
grid = Image.new('RGB', size=(num_cols * width, num_rows * height))

for idx, img in enumerate(generated_images):
    grid.paste(img, box=(idx % num_cols * width, idx // num_cols * height))

# Display the grid
grid.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=384x256 at 0x7FBC713352A0>

# %% [markdown]
# # Analysis:
# The model is not fully trained. To create high quality images we still need to go through multiple epochs of trainings
